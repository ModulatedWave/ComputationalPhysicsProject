# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
import matplotlib as mpl
plt.style.use('science')

mpl.rcParams['font.size'] = 15

# Set major tick size
mpl.rcParams['xtick.major.size'] = 0
mpl.rcParams['ytick.major.size'] = 0

# Set minor tick size
mpl.rcParams['xtick.minor.size'] = 0
mpl.rcParams['ytick.minor.size'] = 0

# %%
J1 = np.loadtxt('CSS_data/J/J_1_N_5000.txt')
J12_01 = np.loadtxt('CSS_data/J1-J2/N_1000_J1_0_J2_1.txt')
J12_11 = np.loadtxt('CSS_data/J1-J2/N_1000_J1_1_J2_1.txt')
J12_12 = np.loadtxt('CSS_data/J1-J2/N_1000_J1_1_J2_2.txt')
J12_21 = np.loadtxt('CSS_data/J1-J2/N_1000_J1_2_J2_1.txt')
J123_001 = np.loadtxt('CSS_data/J1-J2-J3/J1_0_J2_0_J3_1.txt')
J123_101 = np.loadtxt('CSS_data/J1-J2-J3/J1_1_J2_0_J3_1.txt')
J123_111 = np.loadtxt('CSS_data/J1-J2-J3/J1_1_J2_1_J3_1.txt')
J123_124 = np.loadtxt('CSS_data/J1-J2-J3/J1_1_J2_2_J3_4.txt')
J123_421 = np.loadtxt('CSS_data/J1-J2-J3/J1_4_J2_2_J3_1.txt')

# %%
plt.figure(figsize=(5, 4))
plt.imshow(J1, aspect='auto', cmap='seismic', origin='lower')
plt.colorbar(label=r'$C(r, t)$')
plt.xlabel(r'$r$')
plt.ylabel(r'$t$')
plt.xticks([0, 512, 1024, 1536, 2048], [r'$-1000$', r'$-500$', r'$0$', r'$500$', r'$1000$'], fontsize=15)
plt.yticks([0, 1000, 2000, 3000, 4000], [r'$0$', r'$100$', r'$200$', r'$300$', r'$400$'])
plt.savefig('figures/J1.pdf')

# %%
plt.figure(figsize=(5, 4))
plt.imshow(J12_01, aspect='auto', cmap='seismic', origin='lower')
plt.colorbar(label=r'$C(r, t)$')
plt.xlabel(r'$r$')
plt.ylabel(r'$t$')
plt.title(r'$J_1 = 0, J_2 = 1$')
plt.xticks([0, 512, 1024, 1536, 2048], [r'$-1000$', r'$-500$', r'$0$', r'$500$', r'$1000$'], fontsize=15)
plt.yticks([0, 1000, 2000, 3000, 4000], [r'$0$', r'$100$', r'$200$', r'$300$', r'$400$'])
plt.savefig('figures/J12_01.pdf')

# %%
plt.figure(figsize=(5, 4))
plt.imshow(J12_11[0:1500], aspect='auto', cmap='seismic', origin='lower')
plt.colorbar(label=r'$C(r, t)$')
plt.xlabel(r'$r$')
plt.ylabel(r'$t$')
plt.title(r'$J_1 = 1, J_2 = 1$')
plt.xticks([0, 512, 1024, 1536, 2048], [r'$-1000$', r'$-500$', r'$0$', r'$500$', r'$1000$'], fontsize=15)
plt.yticks([0, 500, 1000, 1500], [r'$0$', r'$500$', r'$100$', r'$150$'])
plt.savefig('figures/J12_11.pdf')

# %%
plt.figure(figsize=(5, 4))
plt.imshow(J12_12[0:1500], aspect='auto', cmap='seismic', origin='lower')
plt.colorbar(label=r'$C(r, t)$')
plt.xlabel(r'$r$')
plt.ylabel(r'$t$')
plt.title(r'$J_1 = 1, J_2 = 2$')
plt.xticks([0, 512, 1024, 1536, 2048], [r'$-1000$', r'$-500$', r'$0$', r'$500$', r'$1000$'], fontsize=15)
plt.yticks([0, 500, 1000, 1500], [r'$0$', r'$500$', r'$100$', r'$150$'])
plt.savefig('figures/J12_12.pdf')

# %%
plt.figure(figsize=(5, 4))
plt.imshow(J12_21, aspect='auto', cmap='seismic', origin='lower')
plt.colorbar(label=r'$C(r, t)$')
plt.xlabel(r'$r$')
plt.ylabel(r'$t$')
plt.title(r'$J_1 = 2, J_2 = 1$')
plt.xticks([0, 512, 1024, 1536, 2048], [r'$-1000$', r'$-500$', r'$0$', r'$500$', r'$1000$'], fontsize=15)
plt.yticks([0, 500, 1000, 1500], [r'$0$', r'$500$', r'$100$', r'$150$'])
plt.savefig('figures/J12_21.pdf')

# %%
plt.figure(figsize=(5, 4))
plt.imshow(J123_001, aspect='auto', cmap='seismic', origin='lower')
plt.colorbar(label=r'$C(r, t)$')
plt.xlabel(r'$r$')
plt.ylabel(r'$t$')
plt.title(r'$J_1 = 0, J_2 = 0, J_3 = 1$')
plt.xticks([0, 512, 1024, 1536, 2048], [r'$-1000$', r'$-500$', r'$0$', r'$500$', r'$1000$'], fontsize=15)
plt.yticks([0, 1000, 2000, 3000, 4000], [r'$0$', r'$100$', r'$200$', r'$300$', r'$400$'])
plt.savefig('figures/J123_001.pdf')

# %%
plt.figure(figsize=(5, 4))
plt.imshow(J123_101[0:1500], aspect='auto', cmap='seismic', origin='lower')
plt.colorbar(label=r'$C(r, t)$')
plt.xlabel(r'$r$')
plt.ylabel(r'$t$')
plt.title(r'$J_1 = 1, J_2 = 0, J_3 = 1$')
plt.xticks([0, 512, 1024, 1536, 2048], [r'$-1000$', r'$-500$', r'$0$', r'$500$', r'$1000$'], fontsize=15)
plt.yticks([0, 500, 1000, 1500], [r'$0$', r'$50$', r'$100$', r'$150$'])
plt.savefig('figures/J123_101.pdf')

# %%
plt.figure(figsize=(5, 4))
plt.imshow(J123_111[0:1500], aspect='auto', cmap='seismic', origin='lower')
plt.colorbar(label=r'$C(r, t)$')
plt.xlabel(r'$r$')
plt.ylabel(r'$t$')
plt.title(r'$J_1 = 1, J_2 = 1, J_3 = 1$')
plt.xticks([0, 512, 1024, 1536, 2048], [r'$-1000$', r'$-500$', r'$0$', r'$500$', r'$1000$'], fontsize=15)
plt.yticks([0, 500, 1000, 1500], [r'$0$', r'$50$', r'$100$', r'$150$'])
plt.savefig('figures/J123_111.pdf')

# %%
plt.figure(figsize=(5, 4))
plt.imshow(J123_124, aspect='auto', cmap='seismic', origin='lower')
plt.colorbar(label=r'$C(r, t)$')
plt.xlabel(r'$r$')
plt.ylabel(r'$t$')
plt.title(r'$J_1 = 1, J_2 = 2, J_3 = 4$')
plt.xticks([0, 512, 1024, 1536, 2048], [r'$-1000$', r'$-500$', r'$0$', r'$500$', r'$1000$'], fontsize=15)
plt.yticks([0, 1000, 2000, 3000, 4000], [r'$0$', r'$100$', r'$200$', r'$300$', r'$400$'])
plt.savefig('figures/J123_124.pdf')

# %%
plt.figure(figsize=(5, 4))
plt.imshow(J123_421, aspect='auto', cmap='seismic', origin='lower')
plt.colorbar(label=r'$C(r, t)$')
plt.xlabel(r'$r$')
plt.ylabel(r'$t$')
plt.title(r'$J_1 = 4, J_2 = 2, J_3 = 1$')
plt.xticks([0, 512, 1024, 1536, 2048], [r'$-1000$', r'$-500$', r'$0$', r'$500$', r'$1000$'], fontsize=15)
plt.yticks([0, 1000, 2000, 3000, 4000], [r'$0$', r'$100$', r'$200$', r'$300$', r'$400$'])
plt.savefig('figures/J123_421.pdf')
